# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Out:
# Image: collage 10240.png, shape: (7680, 10240, 3)
# Parts count: 4, shape of one part: (1920, 10240, 3)

# %%
kernel_relief = np.array([[-2, -1, 0],
                          [-1,  1, 1],
                          [ 0,  1, 2]])

# %%
kernel_relief.shape[0] // 2
# Out:
# 1

# %%
import numpy as np
a = []

a.append(10)
a.append(20)

b = len(a)
a.clear()
print(a)
print(b)
# Out:
# []
# 2

# %%
import matplotlib.pyplot as plt
import re
from collections import defaultdict

# Данные
file_content = """
processes: 1
task_time = 14.475446939468384
task_time = 10.48185682296753
task_time = 6.876216173171997
task_time = 7.220076084136963
task_time = 6.199229001998901
processes: 2
task_time = 4.77557110786438
task_time = 5.032052516937256
task_time = 4.7970664501190186
task_time = 4.8431055545806885
task_time = 4.83780837059021
processes: 4
task_time = 4.957233190536499
task_time = 4.920474290847778
task_time = 4.94714093208313
task_time = 4.9445319175720215
task_time = 5.033066034317017
processes: 6
task_time = 5.5174314975738525
task_time = 5.276166200637817
task_time = 5.328756332397461
task_time = 5.338594198226929
task_time = 5.264630079269409
processes: 8
task_time = 5.860892057418823
task_time = 5.85207724571228
task_time = 5.879082202911377
task_time = 5.856234312057495
task_time = 5.848374128341675
processes: 12
task_time = 7.080087900161743
task_time = 7.24364447593689
task_time = 7.176748037338257
task_time = 7.612695217132568
task_time = 7.2560505867004395
"""

# Обработка данных
process_task_times = defaultdict(list)
current_processes = None

for line in file_content.splitlines():
    process_match = re.match(r"processes: (\d+)", line)
    task_time_match = re.match(r"task_time = ([\d.]+)", line)

    if process_match:
        current_processes = int(process_match.group(1))
    elif task_time_match and current_processes is not None:
        process_task_times[current_processes].append(float(task_time_match.group(1)))

# Визуализация
task_times = list(process_task_times.values())
labels = list(process_task_times.keys())

plt.figure(figsize=(10, 6))
plt.hist(task_times, bins=10, label=[f'{p} processes' for p in labels], alpha=0.7, edgecolor='black')
plt.xlabel('Task Time')
plt.ylabel('Frequency')
plt.title('Task Time Distribution for Different Process Counts')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import re
from collections import defaultdict

# Данные
file_content = """
processes: 1
task_time = 6.876216173171997
task_time = 7.220076084136963
task_time = 6.199229001998901
processes: 2
task_time = 4.77557110786438
task_time = 5.032052516937256
task_time = 4.7970664501190186
task_time = 4.8431055545806885
task_time = 4.83780837059021
processes: 4
task_time = 4.957233190536499
task_time = 4.920474290847778
task_time = 4.94714093208313
task_time = 4.9445319175720215
task_time = 5.033066034317017
processes: 6
task_time = 5.5174314975738525
task_time = 5.276166200637817
task_time = 5.328756332397461
task_time = 5.338594198226929
task_time = 5.264630079269409
processes: 8
task_time = 5.860892057418823
task_time = 5.85207724571228
task_time = 5.879082202911377
task_time = 5.856234312057495
task_time = 5.848374128341675
processes: 12
task_time = 7.080087900161743
task_time = 7.24364447593689
task_time = 7.176748037338257
task_time = 7.612695217132568
task_time = 7.2560505867004395
"""

# Обработка данных
process_task_times = defaultdict(list)
current_processes = None

for line in file_content.splitlines():
    process_match = re.match(r"processes: (\d+)", line)
    task_time_match = re.match(r"task_time = ([\d.]+)", line)

    if process_match:
        current_processes = int(process_match.group(1))
    elif task_time_match and current_processes is not None:
        process_task_times[current_processes].append(float(task_time_match.group(1)))

# Визуализация
labels = list(process_task_times.keys())
data = [process_task_times[p] for p in labels]

plt.figure(figsize=(10, 6))
plt.boxplot(data, labels=[f'{p} processes' for p in labels], patch_artist=True, boxprops=dict(facecolor='lightblue', color='blue'))
plt.xlabel('Number of Processes')
plt.ylabel('Task Time')
plt.title('Boxplot of Task Time for Different Process Counts')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Ruslan\AppData\Local\Temp\ipykernel_2256\3951042700.py:61: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=[f'{p} processes' for p in labels], patch_artist=True, boxprops=dict(facecolor='lightblue', color='blue'))

# %%
import requests

# URL публичной базы доменов (пример)
url = "https://public-dns.info/nameservers.txt"

response = requests.get(url)
if response.status_code == 200:
    domains = [line.strip() for line in response.text.splitlines() if line.endswith(".ru")]
    with open("custom_ru.txt", "w") as file:
        file.write("\n".join(domains))
    print("Список доменов сохранен в custom_ru.txt")
else:
    print("Не удалось получить список доменов")
# Out:
# Список доменов сохранен в custom_ru.txt
